# %%
i=0;
markers = ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd',]
plt.figure(figsize=(13,8))
plt.title("Combinations of Detectors / Descriptors")
plt.xlabel('average number of matches')
plt.ylabel('frames/sec')
with open('data/result.txt') as infile:
  for line in infile:
    fields = line.strip().split()
    plt.plot( float(fields[1]), float(fields[2]), markers[i%11], label="'{0}".format(fields[0]))
    i = i+1
plt.legend(bbox_to_anchor=(1.0, 1.0), ncol=2)
plt.savefig('report.img/matches_exectime.png')
